# %% [markdown]
# <a href="https://colab.research.google.com/github/Shruti38-Learner/Python/blob/main/Manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
order = '1,2022-10-01 00:00:00.0,1,COMPLETE'

# %%
type(order)
# Out:
# str

# %%
str.split?

# %%
order.split(sep=',')
# Out:
# ['1', '2022-10-01 00:00:00.0', '1', 'COMPLETE']

# %%
order.split(sep=',')[0]
# Out:
# '1'

# %%
order.split(sep=',')[1]
# Out:
# '2022-10-01 00:00:00.0'

# %%
order.split(sep=',')[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-72d6105db0c6> in <cell line: 1>()
# ----> 1 order.split(sep=',')[4]
#
# IndexError: list index out of range

# %%
order.split(sep=',')[3].lower()
# Out:
# 'complete'
