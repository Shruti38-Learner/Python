# %% [markdown]
# <a href="https://colab.research.google.com/github/Shruti38-Learner/Python/blob/main/List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=['1','2','3','4','5']

# %%
##append(): Add an element to the end of the list.##

# %%
a.append(6)

# %%
print(a)
# Out:
# ['1', '2', '3', '4', '5', 6]

# %%
##insert(): Insert an element at a specific position.##

# %%
a.insert(2,4)

# %%
print(a)
# Out:
# ['1', '2', 4, '3', '4', '5', 6]

# %%
##remove(): Remove the first occurrence of an element##

# %%
a.remove(4)

# %%
print(a)
# Out:
# ['1', '2', '4', '5']

# %%
#pop(): Remove and return an element at a specific index (defaults to the last element if index is not specified)#

# %%
a.pop(2)
# Out:
# '3'

# %%
print(a)
# Out:
# ['1', '2', '4', '5', 6]

# %%
##index(): Find the index of the first occurrence of a value##

# %%
index=a.index(6)

# %%
print(index)
# Out:
# 4

# %%
##count(): Count the occurrences of a value##

# %%
a.count(7)
# Out:
# 0

# %%
#reverse(): Reverse the list in place.#

# %%
a.reverse()

# %%
print(a)
# Out:
# [6, '5', '4', '2', '1']

# %%
#sort(): Sort the list in ascending order in place#

# %%
b=[10,12,9,2,1]

# %%
b.sort()

# %%
print(b)
# Out:
# [1, 2, 9, 10, 12]
